# %% [markdown]
# # Fundamentos de Python
#
# La libreta de Python permite crear celdas de código con instrucciones de Python y ejecutarlas directamente, obteniendo los resultados de la última ejecución.
#
# Podemos agregar texto entre las celdas para documentar los códigos.

# %%
print("Hola")
# Out:
# Hola
# Hola

# %% [markdown]
# ## Variables
#
# Una variable retiene datos en un programa y persiste hasta que el programa finaliza, en la libreta una variable existirá siempre.
#
# Los datos posibles de las variables son:
#
# | Tipo | Ejemplo | Descripción |
# |---|---|---|
# |`str`| `"Hola Python 🐍"` | Retiene un texto con comillas simples o dobles (es lo mismo pero se alternan) |
# |`int`| `123` | Retiene un número entero |
# |`float`| `1.23456` | Retiene un número decimal |
# |`bool`| `True`, `False` | Retiene un valor lógico verdadero o falso |
# |`Nonetype`| `None` | Retiene un valor nulo |

# %%
# Este es un comentario y el texto es irrelevante

nombre = "Ana"
apellidos = "Ming"
edad = 23
casado = False
trabaja = True
estudia = True
frecuencia = 12 + 3.5j # Número complejo
color_favorito = None # No definido

print("Nombre:", nombre)
print("Apellidos:", apellidos)
print("Edad:", edad, "años")
print("Casado?", casado)
print("Trabaja?", trabaja)
print("Estudia?", estudia)
print("Frecuencia:", frecuencia)
print("Color Favorito:", color_favorito)
# Out:
# Nombre: Ana
# Apellidos: Ming
# Edad: 23 años
# Casado? False
# Trabaja? True
# Estudia? True
# Frecuencia: (12+3.5j)
# Color Favorito: None

# %%
type(nombre)
# Out:
# str

# %%
type(casado)
# Out:
# bool

# %%
if type(edad) == int:
  print("La edad es un número entero")
# Out:
# La edad es un número entero

# %%
assert type(edad) == int

# %%
assert not edad > 100 or edad < 0

# %% [markdown]
# ## Formato de Textos
#
# Podemos generar textos que incluyan información de las variables.

# %% [markdown]
# ### `f-string` o Formato de Incrustación

# %%
texto = f"Hola me llamo {nombre}, y tengo {edad} años"

print(texto)
# Out:
# Hola me llamo Ana, y tengo 23 años

# %% [markdown]
# ### `string-format` o Texto con Formato
#
# Los textos con formato pueden ser ajustados de forma avanzada.

# %%
plantilla = "Hola me llamo {}, y tengo {} años"
texto = plantilla.format(nombre, edad)

print(texto)
# Out:
# Hola me llamo Ana, y tengo 23 años

# %% [markdown]
# ### **EJEMPLO:** Recibo de Compra

# %%
productos = [
    (123, 'Coca Cola', 17.5), # -> producto -> (id, nombre, precio) -> 3-tupla
    (124, 'Gansito', 21.5),
    (142, 'Galletas Marías', 14.5),
    (189, 'Nito', 16.99),
    (231, 'Leche Alpura', 21.3333333333333333),
    (355, 'Yoplait', 11.761),
]

recibo = ""

for id, nombre, precio in productos:
  # recibo += f"[{id}] {nombre} ${precio}\n"
  recibo += "[{}] {:<20s} ${:.2f}\n".format(id, nombre, precio)
  # recibo += "[{}] {:^20s} ${:.2f}\n".format(id, nombre, precio)
  # recibo += "[{}] {:>20s} ${:.2f}\n".format(id, nombre, precio)

print(recibo)
# Out:
# [123] Coca Cola            $17.50
# [124] Gansito              $21.50
# [142] Galletas Marías      $14.50
# [189] Nito                 $16.99
# [231] Leche Alpura         $21.33
# [355] Yoplait              $11.76

# %% [markdown]
# ## Colecciones
#
# Existen tres colecciones importantes:
#
# * Listas - Almacenan datos dinámicamente (se pueden extender o vaciar)
# * Tuplas - Empaquetan valores en forma de una variable especial llamada `n-tupla`
# * Diccionarios - Almacenan los valores ligados a una clave (se pueden extender o contraer)

# %% [markdown]
# ### Listas
#
# Permiten operar una colección datos con los siguientes métodos:
#
# - `lista.append(elemento)` - Agrega un elemento al final
# - `lista.insert(índice, elemento)` - Agrega un elemento en el índice y recorre a la derecha los demás elementos
# - `lista.pop()` - Quita el último elemento (puede fallar)
# - `lista.pop(índice)` - Quita el elemento del índice (puede fallar)
# - `lista.remove(elemento)` - Quita el primer elemento idéntico (puede fallar)
# - `lista.count(elemento)` - Determina un entero con el número de elementos repetidos o cero

# %%
frutas = ["manzana", "pera", "kiwi"] # 0-manzana | 1-pera | 2-kiwi

frutas.append('mango') # 0-manzana | 1-pera | 2-kiwi | 3-mango
frutas.insert(2, 'guayaba') # 0-manzana | 1-pera | 2-guayaba | 3-kiwi | 4-mango

print(frutas)
# Out:
# ['manzana', 'pera', 'guayaba', 'kiwi', 'mango']

# %%
print(list(enumerate(frutas)))
# Out:
# [(0, 'manzana'), (1, 'pera'), (2, 'guayaba'), (3, 'kiwi'), (4, 'mango')]

# %%
[fruta for fruta in frutas]
# Out:
# ['manzana', 'pera', 'guayaba', 'kiwi', 'mango']

# %%
[f"{indice}-{fruta}" for indice, fruta in enumerate(frutas)]
# Out:
# ['0-manzana', '1-pera', '2-guayaba', '3-kiwi', '4-mango']

# %%
"\n".join([f"{indice}-{fruta}" for indice, fruta in enumerate(frutas)])
# Out:
# '0-manzana\n1-pera\n2-guayaba\n3-kiwi\n4-mango'

# %%
print("\n".join([f"{indice}-{fruta}" for indice, fruta in enumerate(frutas)]))
# Out:
# 0-manzana
# 1-pera
# 2-guayaba
# 3-kiwi
# 4-mango

# %%
x = [1, 2, 3, 4, 5, 6, 9, 99]

y = [xi ** 2 for xi in x]

y
# Out:
# [1, 4, 9, 16, 25, 36, 81, 9801]

# %%
x = [1, 2, 3, 4, 5, 6, 9, 99]

y = [xi ** 2 for xi in x if xi >= 4 and xi < 10]

y
# Out:
# [16, 25, 36, 81]

# %% [markdown]
# ### Tuplas (Valores empaquetados/acoplados)
#
# Los valores acoplados son valores fusionados en una tupla o paquete de valores que agrupa dichos valores para transportarlos o almacenarlos en cantidad.

# %%
persona1 = ('Ana Ming', 23, 56.7)
persona2 = ('Diego Green', 18, 87.5)
persona3 = 'Bety Sims', 24, 65.4

persona1, persona2, persona3
# Out:
# (('Ana Ming', 23, 56.7), ('Diego Green', 18, 87.5), ('Bety Sims', 24, 65.4))

# %%
# LISTA [ elemento1, elemento2, elemento3, ... ]
# TUPLA ( valor1, valor2, valor3, ... )

personas = [persona1, persona2, persona3, ('Paco White', 32, 98.7)]

personas
# Out:
# [('Ana Ming', 23, 56.7),
#  ('Diego Green', 18, 87.5),
#  ('Bety Sims', 24, 65.4),
#  ('Paco White', 32, 98.7)]

# %%
nombre, edad, peso = persona1 # Desacoplar / Destuplar / Desempaquetar

print(f"La persona se llama {nombre}, tiene {edad} años y pesa {peso} kg")
# Out:
# La persona se llama Ana Ming, tiene 23 años y pesa 56.7 kg

# %%
len(persona1)
# Out:
# 3

# %%
for persona in personas:
  nombre, edad, peso = persona
  print(f"La persona se llama {nombre}, tiene {edad} años y pesa {peso} kg")
# Out:
# La persona se llama Ana Ming, tiene 23 años y pesa 56.7 kg
# La persona se llama Diego Green, tiene 18 años y pesa 87.5 kg
# La persona se llama Bety Sims, tiene 24 años y pesa 65.4 kg
# La persona se llama Paco White, tiene 32 años y pesa 98.7 kg

# %%
for nombre, edad, peso in personas:
  print(f"La persona se llama {nombre}, tiene {edad} años y pesa {peso} kg")
# Out:
# La persona se llama Ana Ming, tiene 23 años y pesa 56.7 kg
# La persona se llama Diego Green, tiene 18 años y pesa 87.5 kg
# La persona se llama Bety Sims, tiene 24 años y pesa 65.4 kg
# La persona se llama Paco White, tiene 32 años y pesa 98.7 kg

# %%
[nombre for nombre, edad, peso in personas]
# Out:
# ['Ana Ming', 'Diego Green', 'Bety Sims', 'Paco White']

# %%
[edad for nombre, edad, peso in personas]
# Out:
# [23, 18, 24, 32]

# %%
[peso for nombre, edad, peso in personas]
# Out:
# [56.7, 87.5, 65.4, 98.7]

# %%
[edad / peso for nombre, edad, peso in personas]
# Out:
# [0.4056437389770723,
#  0.2057142857142857,
#  0.36697247706422015,
#  0.3242147922998987]

# %%
[f"{edad}-{nombre}" for nombre, edad, peso in personas]
# Out:
# ['23-Ana Ming', '18-Diego Green', '24-Bety Sims', '32-Paco White']

# %%
nombres = ["Karol G", "Maluma", "Beto Cuevas", "Rosalia", "Peso Pluma"]
edades = [14, 56, 32, 34, 57]
pesos = [98.5, 76, 43, 56.7, 76.5]

personas = list(zip(nombres, edades, pesos))

personas
# Out:
# [('Karol G', 14, 98.5),
#  ('Maluma', 56, 76),
#  ('Beto Cuevas', 32, 43),
#  ('Rosalia', 34, 56.7),
#  ('Peso Pluma', 57, 76.5)]

# %%
nombres, edades, pesos = zip(*personas)

print(nombres)
print(edades)
print(pesos)
# Out:
# ('Karol G', 'Maluma', 'Beto Cuevas', 'Rosalia', 'Peso Pluma')
# (14, 56, 32, 34, 57)
# (98.5, 76, 43, 56.7, 76.5)

# %% [markdown]
# ### Diccionarios (Almacén Clave-Valor)
#
# Un diccionario es un contenedor de claves y valores asociados.

# %%
# persona = ('Ana Ming', 23, 57.6) # Complejo y hay que recordar el orden

persona = {
    "nombre": "Ana Ming",
    "edad": 23,
    "peso": 57.6
}

print(persona)
# Out:
# {'nombre': 'Ana Ming', 'edad': 23, 'peso': 57.6}

# %%
persona["nombre"]
# Out:
# 'Ana Ming'

# %%
persona["edad"]
# Out:
# 23

# %%
persona["peso"]
# Out:
# 57.6

# %%
if "x" in persona:
  print(persona["x"])
else:
  print("La persona no tiene la clave 'x'")
# Out:
# La persona no tiene la clave 'x'

# %% [markdown]
# ## Funciones (Tareas / Operaciones / Actividades / Métodos)
#
# Las funciones son fragmentos de entrada-salida reutilizables que se pueden llamar con diferentes parámetros de entrada para provocar una salida, que si no está definida será `None` por defecto.

# %%
def suma(a, b):
  return a + b

suma(1, 2)
# Out:
# 3

# %%
suma(100, 200)
# Out:
# 300

# %%
def division(a, b):
  assert not b == 0
  return a / b

c = division(1, 4)

c
# Out:
# 0.25

# %%
# division(1, 0) # AssertError
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-75-b99a52eb0fb3> in <cell line: 1>()
# ----> 1 division(1, 0) # AssertError
#
# <ipython-input-74-e6a6aab81c7d> in division(a, b)
#       1 def division(a, b):
# ----> 2   assert not b == 0
#       3   return a / b
#       4
#       5 c = division(1, 4)
#
# AssertionError:

# %%
def descargar_imagen(url):
  import requests
  response = requests.get(url)
  assert response.ok
  imagen = response.content
  return imagen

batman_img = descargar_imagen("https://m.media-amazon.com/images/I/518YabTa8YL._AC_UF894,1000_QL80_.jpg")

with open("batman.jpg", "wb") as file:
  file.write(batman_img)

len(batman_img)
# Out:
# 37100

# %%
import matplotlib.pyplot as plt # Importación con alias "matplotlib.pyplot -> plt"
from PIL import Image

batman_img2 = Image.open('batman.jpg')

plt.imshow(batman_img2)
plt.show()

# %%
def escribir_imagen(nombre, imagen):
  with open(nombre, "wb") as file:
    file.write(imagen)
    print(f"Imagen guardada: {nombre}")
    print(f"Se escribieron {len(imagen)} bytes")

escribir_imagen("batman_demo.jpg", batman_img)
# Out:
# Imagen guardada: batman_demo.jpg
# Se escribieron 37100 bytes

# %%
def mostrar_imagen(nombre):
  import matplotlib.pyplot as plt
  from PIL import Image

  imagen = Image.open(nombre)

  plt.imshow(imagen)
  plt.show()

mostrar_imagen("batman.jpg")

# %%
mostrar_imagen("robin.png")
